# %%
# %pylab inline
from subprocess import call
import os.path
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def data_base_query(query, outputfile, password="42", username="forero"):
    website = "http://wget.multidark.org/MyDB?action=doQuery&SQL="
    wget_options="--auth-no-challenge --content-disposition --cookies=on --keep-session-cookies --save-cookies=cookie.txt --load-cookies=cookie.txt" 
    wget_options=wget_options+" -O "+outputfile +" "
    wget_command="wget --http-user="+username+" --http-passwd="+password+" "+wget_options
    command = wget_command + "\""+ website + query+"\""
    #print command
    retcode = call(command,shell=True)

# %% [markdown]
# Load some haloID data corresponding to a subbox of 20Mpc/h from MultiDark

# %%
halo_filename = '../data/halo_ID/MD_subbox_450_550_halo_ID.csv'
halo_data = loadtxt(halo_filename, delimiter=',',skiprows=16)

# %%
x = halo_data[:,1]
y = halo_data[:,2]

# %%
scatter(x,y,s=0.1)

# %%
fofID = int_(halo_data[:,0])
n_particles = int_(halo_data[:,4])
#n_halos = size(fofID)
max_n_particles = 10000
n_halos = 500

# %%
for halo_ID in range(n_halos):
    particle_query = "select p.* from MDR1..FOFParticles f, MDR1..particles p\
 where f.fofParticleId like '%d_%s'\
 and f.particleId = p.particleId\
 order by f.fofParticleId asc"%(fofID[halo_ID],"%")
    output_file = "../data/particle_ID/halo_%d_particle_ID.csv"%(fofID[halo_ID])
    if( (not os.path.exists(output_file)) and (n_particles[halo_ID] < max_n_particles )):
        print output_file
        n = data_base_query(particle_query, output_file, password="")
# Out:
# ../data/particle_ID/halo_85002736503_particle_ID.csv
# ../data/particle_ID/halo_85002751894_particle_ID.csv
# ../data/particle_ID/halo_85002752055_particle_ID.csv
# ../data/particle_ID/halo_85002753768_particle_ID.csv
# ../data/particle_ID/halo_85002788589_particle_ID.csv
# ../data/particle_ID/halo_85002788600_particle_ID.csv
# ../data/particle_ID/halo_85002806451_particle_ID.csv
# ../data/particle_ID/halo_85002806457_particle_ID.csv
# ../data/particle_ID/halo_85002841148_particle_ID.csv
# ../data/particle_ID/halo_85002842877_particle_ID.csv
# ../data/particle_ID/halo_85002842881_particle_ID.csv
# ../data/particle_ID/halo_85002842882_particle_ID.csv
# ../data/particle_ID/halo_85002861241_particle_ID.csv
# ../data/particle_ID/halo_85002878008_particle_ID.csv
# ../data/particle_ID/halo_85002880134_particle_ID.csv
# ../data/particle_ID/halo_85002880140_particle_ID.csv
# ../data/particle_ID/halo_85002880142_particle_ID.csv
# ../data/particle_ID/halo_85002898996_particle_ID.csv
# ../data/particle_ID/halo_85002898997_particle_ID.csv
# ../data/particle_ID/halo_85002899002_particle_ID.csv
# ../data/particle_ID/halo_85002918378_particle_ID.csv
# ../data/particle_ID/halo_85002918380_particle_ID.csv
# ../data/particle_ID/halo_85002918381_particle_ID.csv
# ../data/particle_ID/halo_85002918383_particle_ID.csv
# ../data/particle_ID/halo_85002918390_particle_ID.csv
# ../data/particle_ID/halo_85002935970_particle_ID.csv
# ../data/particle_ID/halo_85002937768_particle_ID.csv
# ../data/particle_ID/halo_85002955651_particle_ID.csv
# ../data/particle_ID/halo_85002957779_particle_ID.csv
# ../data/particle_ID/halo_85002957783_particle_ID.csv
# ../data/particle_ID/halo_85002976181_particle_ID.csv
# ../data/particle_ID/halo_85002978054_particle_ID.csv
# ../data/particle_ID/halo_85002978056_particle_ID.csv
# ../data/particle_ID/halo_85002978059_particle_ID.csv
# ../data/particle_ID/halo_85002998584_particle_ID.csv
# ../data/particle_ID/halo_85002998585_particle_ID.csv
# ../data/particle_ID/halo_85002998586_particle_ID.csv
# ../data/particle_ID/halo_85002998587_particle_ID.csv
# ../data/particle_ID/halo_85002998594_particle_ID.csv
# ../data/particle_ID/halo_85002998595_particle_ID.csv
# ../data/particle_ID/halo_85003019120_particle_ID.csv
# ../data/particle_ID/halo_85003035493_particle_ID.csv
# ../data/particle_ID/halo_85003040058_particle_ID.csv
# ../data/particle_ID/halo_85003059101_particle_ID.csv
# ../data/particle_ID/halo_85003061407_particle_ID.csv
# ../data/particle_ID/halo_85003061412_particle_ID.csv
# ../data/particle_ID/halo_85003061421_particle_ID.csv
# ../data/particle_ID/halo_85003081121_particle_ID.csv
# ../data/particle_ID/halo_85003083328_particle_ID.csv
# ../data/particle_ID/halo_85003102759_particle_ID.csv
# ../data/particle_ID/halo_85003105219_particle_ID.csv
# ../data/particle_ID/halo_85003122677_particle_ID.csv
# ../data/particle_ID/halo_85003127383_particle_ID.csv
# ../data/particle_ID/halo_85003127385_particle_ID.csv
# ../data/particle_ID/halo_85003127386_particle_ID.csv
# ../data/particle_ID/halo_85003127392_particle_ID.csv
# ../data/particle_ID/halo_85003147423_particle_ID.csv
# ../data/particle_ID/halo_85003147623_particle_ID.csv
# ../data/particle_ID/halo_85003149987_particle_ID.csv
# ../data/particle_ID/halo_85003149989_particle_ID.csv
# ../data/particle_ID/halo_85003170905_particle_ID.csv
# ../data/particle_ID/halo_85003173077_particle_ID.csv
# ../data/particle_ID/halo_85003173083_particle_ID.csv
# ../data/particle_ID/halo_85003173089_particle_ID.csv
# ../data/particle_ID/halo_85003193973_particle_ID.csv
# ../data/particle_ID/halo_85003196661_particle_ID.csv
# ../data/particle_ID/halo_85003196662_particle_ID.csv
# ../data/particle_ID/halo_85003196663_particle_ID.csv
# ../data/particle_ID/halo_85003217671_particle_ID.csv
# ../data/particle_ID/halo_85003220400_particle_ID.csv
# ../data/particle_ID/halo_85003220402_particle_ID.csv
# ../data/particle_ID/halo_85003220410_particle_ID.csv
# ../data/particle_ID/halo_85003239353_particle_ID.csv
# ../data/particle_ID/halo_85003239354_particle_ID.csv
# ../data/particle_ID/halo_85003244528_particle_ID.csv
# ../data/particle_ID/halo_85003244542_particle_ID.csv
# ../data/particle_ID/halo_85003268791_particle_ID.csv
# ../data/particle_ID/halo_85003268803_particle_ID.csv
# ../data/particle_ID/halo_85003318708_particle_ID.csv
# ../data/particle_ID/halo_85003318709_particle_ID.csv
# ../data/particle_ID/halo_85003344403_particle_ID.csv
# ../data/particle_ID/halo_85003344409_particle_ID.csv
# ../data/particle_ID/halo_85003344410_particle_ID.csv
# ../data/particle_ID/halo_85003367835_particle_ID.csv
# ../data/particle_ID/halo_85003370271_particle_ID.csv
# ../data/particle_ID/halo_85003370277_particle_ID.csv
# ../data/particle_ID/halo_85003370278_particle_ID.csv
# ../data/particle_ID/halo_85003370281_particle_ID.csv
# ../data/particle_ID/halo_85003370284_particle_ID.csv
# ../data/particle_ID/halo_85003390927_particle_ID.csv
# ../data/particle_ID/halo_85003396569_particle_ID.csv
# ../data/particle_ID/halo_85003396585_particle_ID.csv
# ../data/particle_ID/halo_85003423648_particle_ID.csv
# ../data/particle_ID/halo_85003445047_particle_ID.csv
# ../data/particle_ID/halo_85003448029_particle_ID.csv
# ../data/particle_ID/halo_85003451091_particle_ID.csv
# ../data/particle_ID/halo_85003451093_particle_ID.csv
# ../data/particle_ID/halo_85003451095_particle_ID.csv
# ../data/particle_ID/halo_85003451096_particle_ID.csv
# ../data/particle_ID/halo_85003451099_particle_ID.csv
# ../data/particle_ID/halo_85003478855_particle_ID.csv
# ../data/particle_ID/halo_85003478863_particle_ID.csv
# ../data/particle_ID/halo_85003478867_particle_ID.csv
# ../data/particle_ID/halo_85003507083_particle_ID.csv
# ../data/particle_ID/halo_85003507085_particle_ID.csv
# ../data/particle_ID/halo_85003507088_particle_ID.csv
# ../data/particle_ID/halo_85003507097_particle_ID.csv
# ../data/particle_ID/halo_85003535419_particle_ID.csv
# ../data/particle_ID/halo_85003535426_particle_ID.csv
# ../data/particle_ID/halo_85003561532_particle_ID.csv
# ../data/particle_ID/halo_85003564306_particle_ID.csv
# ../data/particle_ID/halo_85003564314_particle_ID.csv
# ../data/particle_ID/halo_85003564323_particle_ID.csv
# ../data/particle_ID/halo_85003590527_particle_ID.csv
# ../data/particle_ID/halo_85003593604_particle_ID.csv
# ../data/particle_ID/halo_85003593605_particle_ID.csv
# ../data/particle_ID/halo_85003593611_particle_ID.csv
# ../data/particle_ID/halo_85003593618_particle_ID.csv
# ../data/particle_ID/halo_85003593619_particle_ID.csv
# ../data/particle_ID/halo_85003623716_particle_ID.csv
# ../data/particle_ID/halo_85003623722_particle_ID.csv
# ../data/particle_ID/halo_85003654374_particle_ID.csv
# ../data/particle_ID/halo_85003654378_particle_ID.csv
# ../data/particle_ID/halo_85003654383_particle_ID.csv
# ../data/particle_ID/halo_85003654384_particle_ID.csv
# ../data/particle_ID/halo_85003654387_particle_ID.csv
# ../data/particle_ID/halo_85003654389_particle_ID.csv
# ../data/particle_ID/halo_85003654392_particle_ID.csv
# ../data/particle_ID/halo_85003685350_particle_ID.csv
# ../data/particle_ID/halo_85003685356_particle_ID.csv
# ../data/particle_ID/halo_85003716953_particle_ID.csv
# ../data/particle_ID/halo_85003716959_particle_ID.csv
# ../data/particle_ID/halo_85003716967_particle_ID.csv
# ../data/particle_ID/halo_85003716971_particle_ID.csv
# ../data/particle_ID/halo_85003778623_particle_ID.csv
# ../data/particle_ID/halo_85003778929_particle_ID.csv
# ../data/particle_ID/halo_85003782019_particle_ID.csv
# ../data/particle_ID/halo_85003815569_particle_ID.csv
# ../data/particle_ID/halo_85003815582_particle_ID.csv
# ../data/particle_ID/halo_85003845877_particle_ID.csv
# ../data/particle_ID/halo_85003849391_particle_ID.csv
# ../data/particle_ID/halo_85003849410_particle_ID.csv
# ../data/particle_ID/halo_85003849411_particle_ID.csv
# ../data/particle_ID/halo_85003849414_particle_ID.csv
# ../data/particle_ID/halo_85003884031_particle_ID.csv
# ../data/particle_ID/halo_85003884034_particle_ID.csv
# ../data/particle_ID/halo_85003884035_particle_ID.csv
# ../data/particle_ID/halo_85003884038_particle_ID.csv
# ../data/particle_ID/halo_85003884045_particle_ID.csv
# ../data/particle_ID/halo_85003955238_particle_ID.csv
# ../data/particle_ID/halo_85003955239_particle_ID.csv
# ../data/particle_ID/halo_85003955252_particle_ID.csv
# ../data/particle_ID/halo_85003955255_particle_ID.csv
# ../data/particle_ID/halo_85003991710_particle_ID.csv
# ../data/particle_ID/halo_85003991718_particle_ID.csv
# ../data/particle_ID/halo_85004024907_particle_ID.csv
# ../data/particle_ID/halo_85004063257_particle_ID.csv
